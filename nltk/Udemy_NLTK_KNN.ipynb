# %%
import requests
import urllib2
from bs4 import BeautifulSoup
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from collections import defaultdict
from string import punctuation
from heapq import nlargest
from math import log
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
def getWashPostText(url,token):
    # THis function takes the URL of an article in the 
    # Washington Post, and then returns the article minus all 
    # of the crud - HTML, javascript etc. How? By searching for
    # everything that lies between the tags titled 'token'
    # Like most web-scraping, this will only work for urls where
    # we know the structure (eg say all articles in the WashPo are
    # enclosed in <article></article> tags). This will also change from
    # time to time as different HTML formats are employed in the website
    try:
        page = urllib2.urlopen(url).read().decode('utf8')
    except:
        # if unable to download the URL, return title = None, article = None
        return (None,None)
    soup = BeautifulSoup(page, "lxml")
    if soup is None:
        return (None,None)
    # If we are here, it means the error checks were successful, we were
    # able to parse the page
    text = ""
    if soup.find_all(token) is not None:
        # Search the page for whatever token demarcates the article
        # usually '<article></article>'
        text = ''.join(map(lambda p: p.text, soup.find_all(token)))
        # mush together all the text in the <article></article> tags
        soup2 = BeautifulSoup(text, "lxml")
        # create a soup of the text within the <article> tags
        if soup2.find_all('p')!=[]:
            # now mush together the contents of what is in <p> </p> tags
            # within the <article>
            text = ''.join(map(lambda p: p.text, soup2.find_all('p')))
    return text, soup.title.text
    # what did we just do? Let's go through and understand
    # finally return the result tuple with the title and the body of the article

# %%
def getNYTText(url,token):
    response = requests.get(url)
    # THis is an alternative way to get the contents of a URL
    soup = BeautifulSoup(response.content)
    page = str(soup)
    title = soup.find('title').text
    mydivs = soup.findAll("p", {"class":"story-body-text story-content"})
    text = ''.join(map(lambda p:p.text, mydivs))
    return text, title

# %%
def scrapeSource(url, magicFrag='2015',scraperFunction=getNYTText,token='None'):
    urlBodies = {}
    request = urllib2.Request(url)
    response = urllib2.urlopen(request)
    soup = BeautifulSoup(response)
    # we are set up with a Soup of the page - now find the links
    # Remember that links are always of the form 
    # <a href='link-url'> link-text </a>
    numErrors = 0
    for a in soup.findAll('a'):
        try:
            url = a['href']
            if( (url not in urlBodies) and 
               ((magicFrag is not None and magicFrag in url) 
               or magicFrag is None)):
                body = scraperFunction(url,token)
                # this line above is important - scraperFunction 
                # refers to the individual scraper function for the 
                # new york times or the washington post etc.
                if body and len(body) > 0:
                    urlBodies[url] = body
                print url
        except:
            numErrors += 1
            # plenty of parse errors happen - links might not
            # be external links, might be malformed and so on -
            # so don't mind if there are exceptions.
    return urlBodies

# %%
class FrequencySummarizer:
    def __init__(self,min_cut=0.1,max_cut=0.9):
        # class constructor - takes in min and max cutoffs for 
        # frequency
        self._min_cut = min_cut
        self._max_cut = max_cut
        self._stopwords = set(stopwords.words('english') +
                              list(punctuation) +
                              [u"'s",'"'])
        # notice how the stopwords are a set, not a list. 
        # its easy to go from set to list and vice-versa
        # (simply use the set() and list() functions) - 
        # but conceptually sets are different from lists
        # because sets don't have an order to their elements
        # while lists do
    
    def _compute_frequencies(self,word_sent,customStopWords=None):
        freq = defaultdict(int)
        # we have encountered defaultdict objects before
        if customStopWords is None:
            stopwords = set(self._stopwords)
        else:
            stopwords = set(customStopWords).union(self._stopwords)
        for sentence in word_sent:
            for word in sentence:
                if word not in stopwords:
                    freq[word] += 1
        m = float(max(freq.values()))
        for word in freq.keys():
            freq[word] = freq[word]/m
            if freq[word] >= self._max_cut or freq[word] <= self._min_cut:
                del freq[word]
        return freq
    
    def extractFeatures(self,article,n,customStopWords=None):
        # The article is passed in as a tuple (text, title)
        text = article[0]
        # extract the text
        title = article[1]
        # extract the title
        sentences = sent_tokenize(text)
        # split the text into sentences
        word_sent = [word_tokenize(s.lower()) for s in sentences]
        # split the sentences into words 
        self._freq = self._compute_frequencies(word_sent,customStopWords)
        # calculate the word frequencies using the member function above
        if n < 0:
            # how many features (words) to return? IF the user has
            # asked for a negative number, this is a sign that we don't
            # do any feature selection - we return ALL features
            # THis is feature extraction without any pruning, ie no
            # feature selection (beyond simply picking words as the features)
            return nlargest(len(self._freq.keys()),self._freq,key=self._freq.get)
        else:
            # if the calling function has asked for a subset then
            # return only the 'n' largest features - ie here the most
            # important words (important == frequent, barring stopwords)
            return nlargest(n,self._freq,key=self._freq.get)
        # let's summarize what we did here. 
    
    def extractRawFrequencies(self, article):
        # very similar, except that this method will return the 'raw'
        # frequencies - literally just the word counts
        text = article[0]
        title = article[1]
        sentences = sent_tokenize(text)
        word_sent = [word_tokenize(s.lower()) for s in sentences]
        freq = defaultdict(int)
        for s in word_sent:
            for word in s:
                if word not in self._stopwords:
                    freq[word] += 1
        return freq
    
    def summarize(self, article,n):
        text = article[0]
        title = article[1]
        sentences = sent_tokenize(text)
        word_sent = [word_tokenize(s.lower()) for s in sentences]
        self._freq = self._compute_frequencies(word_sent)
        ranking = defaultdict(int)
        for i,sentence in enumerate(word_sent):
            for word in sentence:
                if word in self._freq:
                    ranking[i] += self._freq[word]
        sentences_index = nlargest(n,ranking,key=ranking.get)

        return [sentences[j] for j in sentences_index]

# %%
urlWashingtonPostNonTech = "https://www.washingtonpost.com/sports"
urlNewYorkTimesNonTech = "https://www.nytimes.com/pages/sports/index.html"
urlWashingtonPostTech = "https://www.washingtonpost.com/business/technology"
urlNewYorkTimesTech = "http://www.nytimes.com/pages/technology/index.html"

washingtonPostTechArticles = scrapeSource(urlWashingtonPostTech,
                                          '2017',
                                         getWashPostText,
                                         'article') 
washingtonPostNonTechArticles = scrapeSource(urlWashingtonPostNonTech,
                                          '2017',
                                         getWashPostText,
                                         'article')
                
                
newYorkTimesTechArticles = scrapeSource(urlNewYorkTimesTech,
                                       '2017',
                                       getNYTText,
                                       None)
newYorkTimesNonTechArticles = scrapeSource(urlNewYorkTimesNonTech,
                                       '2017',
                                       getNYTText,
                                       None)
# Out:
# https://www.washingtonpost.com/news/post-nation/wp/2017/10/28/a-mother-purposely-drove-suv-with-her-three-children-off-a-cliff-police-say/?utm_term=.aa9e9b95ff8f
# https://www.washingtonpost.com/news/worldviews/wp/2017/10/29/a-british-minister-admits-he-made-his-secretary-buy-sex-toys-as-metoo-hits-parliament/?utm_term=.21499faa3451
# https://www.washingtonpost.com/news/the-fix/wp/2017/10/29/a-cyclist-flipped-off-trumps-motorcade-and-entered-the-annals-of-presidential-protests/?utm_term=.0f9d78e691e9
# https://www.washingtonpost.com/news/the-fix/wp/2017/10/29/cnn-broke-news-in-the-russia-probe-roger-stones-resulting-rant-got-him-yanked-off-twitter/?utm_term=.12bb8ef20fd9
# https://www.washingtonpost.com/news/to-your-health/wp/2017/10/28/she-signed-up-to-be-a-surrogate-mother-and-unwittingly-gave-her-own-child-away/?utm_term=.e5449001014f
# https://www.washingtonpost.com/news/worldviews/wp/2017/10/28/nuclear-sub-sailors-fired-after-absolutely-disgraceful-parties-with-a-prostitute-and-cocaine/?utm_term=.eb4725ef6809
# https://www.washingtonpost.com/news/nationals-journal/wp/2017/10/29/dave-martinez-is-nationals-choice-for-manager-but-no-deal-is-done/?utm_term=.4315b558e473
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/25/the-fcc-plans-to-roll-back-some-of-its-biggest-rules-against-media-consolidation/
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/28/best-buy-adds-100-to-the-price-of-the-1000-iphone/
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/27/uber-hires-pepsicos-tony-west-as-general-counsel/
# https://www.washingtonpost.com/business/get-an-obstacle-course-workout-no-matter-where-you-are/2017/10/27/918731ce-b8db-11e7-9e58-e6288544af98_story.html
# https://www.washingtonpost.com/business/when-leaping-off-tall-buildings-in-a-single-bound-helps-you-catch-some-villains/2017/10/27/82857f78-b8db-11e7-9e58-e6288544af98_story.html
# https://www.washingtonpost.com/video/business/technology/this-watch-can-help-the-blind-see-by-using-echolocation/2017/10/27/31a5da1a-ba8b-11e7-9b93-b97043e57a22_video.html
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/26/twitter-says-it-overstated-the-size-of-its-user-base-for-years/
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/26/kingdom-of-saudi-arabia-to-invest-1-billion-in-richard-bransons-space-companies/
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/26/twitter-bans-russian-government-news-sites-rt-and-sputnik-from-buying-ads/
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/25/if-you-want-an-iphone-x-for-the-holidays-start-planning-now/
# https://www.washingtonpost.com/video/business/technology/amazons-new-service-lets-you-open-your-house-door-to-anyone-anytime/2017/10/25/c8deea04-b98a-11e7-9b93-b97043e57a22_video.html
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/24/amid-russian-investigation-twitter-is-making-all-of-its-ads-public/
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/23/amazon-facebook-and-google-beef-up-lobbying-spending/
# https://www.washingtonpost.com/business/tap-that-inner-artist-and-you-may-be-surprised-by-your-creativity/2017/10/20/1c58c464-a957-11e7-92d1-58c702d2d975_story.html
# https://www.washingtonpost.com/business/get-in-the-drivers-seat-for-crazy-car-stunts-in-this-adrenaline-rush-of-a-game/2017/10/20/0f42709a-a957-11e7-92d1-58c702d2d975_story.html
# https://www.washingtonpost.com/news/dr-gridlock/wp/2017/10/19/elon-musks-east-coast-hyperloop-will-launch-digging-in-maryland-state-and-company-say/
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/19/facebook-and-google-might-be-one-step-closer-to-new-regulations-on-ad-transparency/
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/19/rocket-tests-and-wind-farms-jeff-bezos-had-more-on-his-mind-today-than-just-who-wants-to-host-an-amazon-hq/
# https://www.washingtonpost.com/video/business/technology/living-smarter-with-tech-how-to-be-a-better-friend/2017/10/19/6de5c314-b4f0-11e7-9b93-b97043e57a22_video.html
# https://www.washingtonpost.com/news/the-switch/wp/2017/10/19/why-microsoft-released-a-windows-update-with-a-bunch-of-stuff-you-may-never-use/
# https://www.washingtonpost.com/news/the-intersect/wp/2017/10/19/the-woman-behind-me-too-knew-the-power-of-the-phrase-when-she-created-it-10-years-ago/
# https://www.washingtonpost.com/business/economy/puerto-rico-governor-says-contract-to-whitefish-company-should-be-canceled/2017/10/29/e5336cda-bcb8-11e7-97d9-bdab5a0ab381_story.html?tid=pm_business_pop
# https://www.washingtonpost.com/news/innovations/wp/2017/10/29/saudi-arabia-which-denies-women-equal-rights-makes-a-robot-a-citizen/?tid=pm_business_pop
# https://www.washingtonpost.com/business/economy/home-builders-raise-hammer-try-to-smash-gop-tax-bill/2017/10/29/7c473cce-bce0-11e7-97d9-bdab5a0ab381_story.html?tid=pm_business_pop
# https://www.washingtonpost.com/business/economy/in-24-billion-video-game-industry-voice-actors-dont-make-enough-to-live-on/2017/10/27/944a0800-98d8-11e7-87fc-c3f7ee4035c9_story.html?tid=pm_business_pop
# https://www.washingtonpost.com/news/business/wp/2017/10/27/a-wisconsin-man-got-locked-in-a-walk-in-beer-cooler-he-had-everything-that-he-needed-police-say/?tid=pm_business_pop
# https://www.washingtonpost.com/news/wizards-insider/wp/2017/10/29/wizards-bradley-beal-fined-50000-for-fight-with-draymond-green/
# https://www.washingtonpost.com/news/early-lead/wp/2017/10/29/florida-reportedly-parting-ways-with-coach-jim-mcelwain/
# https://www.washingtonpost.com/video/sports/nationals-hire-davey-martinez-as-next-manager/2017/10/29/e90f8c9a-bce9-11e7-9294-705f80164f6e_video.html
# https://www.washingtonpost.com/news/early-lead/wp/2017/10/28/dartmouth-assistant-tossed-for-smashing-window-in-coaches-box-during-loss-to-harvard/
# https://www.washingtonpost.com/news/early-lead/wp/2017/10/28/packers-martellus-bennett-says-hes-pretty-sure-this-nfl-season-is-his-last/?utm_term=.99c07d50e763
# https://www.washingtonpost.com/news/early-lead/wp/2017/10/29/as-catcher-bruce-maxwell-who-knelt-during-national-anthem-arrested-on-gun-charge/
# https://www.washingtonpost.com/news/soccer-insider/wp/2017/10/29/uswnts-crystal-dunn-scores-twice-for-chelsea/
# https://www.washingtonpost.com/sports/redskins-limp-to-seasons-midpoint-after-a-predictable-loss-and-mounting-injuries/2017/10/29/4d4fe5ee-bcca-11e7-959c-fe2b598d8c00_story.html
# https://www.washingtonpost.com/sports/injuries-cowboys-overtake-outmanned-redskins-in-a-sunday-slog/2017/10/29/47b68016-bcca-11e7-959c-fe2b598d8c00_story.html?utm_term=.7104415ce8b6
# http://www.washingtonpost.com/news/dc-sports-bog/wp/2017/10/29/best-and-worst-moments-from-the-redskins-cowboys-game-at-fedex-field/
# http://www.washingtonpost.com/sports/now-playing-offensive-line-for-the-redskins--wait-who-is-that/2017/10/29/03825dea-bc28-11e7-be94-fabb0f1e9ffb_story.html
# https://www.washingtonpost.com/sports/we-couldnt-get-the-mojo-back-blocked-kick-was-the-beginning-of-the-end-for-redskins/2017/10/29/af17323a-bccc-11e7-959c-fe2b598d8c00_story.html
# http://www.washingtonpost.com/blogs/football-insider/wp/2017/10/29/redskins-trent-williams-taking-it-week-by-week-but-says-knee-is-getting-worse/
# https://www.washingtonpost.com/sports/astros-outlast-dodgers-in-an-epic-thriller-of-a-game-5-in-the-world-series/2017/10/30/461291ce-bcc4-11e7-959c-fe2b598d8c00_story.html
# https://www.washingtonpost.com/sports/for-this-world-series-not-enough-superlatives-with-the-astros-and-dodgers/2017/10/30/3cc1a146-bcc4-11e7-959c-fe2b598d8c00_story.html
# https://www.washingtonpost.com/news/nationals-journal/wp/2017/10/29/dave-martinez-is-nationals-choice-for-manager-but-no-deal-is-done/
# https://www.washingtonpost.com/news/wizards-insider/wp/2017/10/29/after-flirtation-with-kings-otto-porter-jr-elevates-his-game-for-the-wizards/
# https://www.washingtonpost.com/news/sports/wp/2017/10/29/nfl-week-8-owner-bob-mcnair-has-texans-on-edge-browns-vikings-start-day-in-london/
# https://www.washingtonpost.com/sports/redskins/nfl-bob-mcnair-demonstrate-their-true-intent-controlling-black-athletes/2017/10/29/437685d4-bcd2-11e7-959c-fe2b598d8c00_story.html
# https://www.washingtonpost.com/news/early-lead/wp/2017/10/30/astros-fan-rips-world-series-home-run-ball-from-other-fans-hand-throws-it-onto-field/
# https://www.washingtonpost.com/sports/capitals/road-weary-and-tired-of-chasing-the-lead-caps-fall-at-calgary-2-1/2017/10/30/1267a2c6-bccc-11e7-959c-fe2b598d8c00_story.html
# https://www.washingtonpost.com/sports/tv-and-radio-listings-october-30/2017/10/30/3fb05a0c-bd26-11e7-8444-a0d4f04b89eb_story.html
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2017/10/29/i-just-wasnt-his-guy-robert-griffin-iii-opens-up-about-jay-gruden-redskins-on-twitter/
# https://www.washingtonpost.com/news/early-lead/wp/2017/10/29/colin-kaepernick-still-looking-to-be-included-in-meetings-between-nfl-and-players/
# https://www.washingtonpost.com/news/football-insider/wp/2017/10/29/redskins-gameday-cowboys-come-to-town-as-redskins-lose-another-offensive-lineman/
# https://www.washingtonpost.com/news/football-insider/wp/2017/10/29/redskins-trent-williams-taking-it-week-by-week-but-says-knee-is-getting-worse/
# https://www.washingtonpost.com/news/sports/wp/2017/10/29/as-texans-owner-reignites-protest-debate-jerry-jones-says-nfl-should-seek-accountability/
# https://www.washingtonpost.com/sports/now-playing-offensive-line-for-the-redskins--wait-who-is-that/2017/10/29/03825dea-bc28-11e7-be94-fabb0f1e9ffb_story.html
# https://www.washingtonpost.com/news/early-lead/wp/2017/10/29/seahawks-michael-bennett-takes-a-knee-after-sacking-texans-deshaun-watson/
# https://www.washingtonpost.com/sports/injuries-cowboys-overtake-outmanned-redskins-in-a-sunday-slog/2017/10/29/47b68016-bcca-11e7-959c-fe2b598d8c00_story.html
# https://www.washingtonpost.com/sports/at-world-series-dodgers-and-astros-deal-with-questions-of-slick-baseballs/2017/10/29/d6d2383c-bcf0-11e7-97d9-bdab5a0ab381_story.html
# https://www.washingtonpost.com/news/sports/wp/2017/10/29/campus-cleanup-only-the-luckiest-people-get-to-live-in-ames-iowa/
# https://www.washingtonpost.com/sports/astros-outlast-dodgers-in-an-epic-thriller-of-a-game-5-in-the-world-series/2017/10/30/461291ce-bcc4-11e7-959c-fe2b598d8c00_story.html?tid=pm_sports_pop
# https://www.washingtonpost.com/news/early-lead/wp/2017/10/30/astros-fan-rips-world-series-home-run-ball-from-other-fans-hand-throws-it-onto-field/?tid=pm_sports_pop
# https://www.washingtonpost.com/sports/for-this-world-series-not-enough-superlatives-with-the-astros-and-dodgers/2017/10/30/3cc1a146-bcc4-11e7-959c-fe2b598d8c00_story.html?tid=pm_sports_pop
# https://www.washingtonpost.com/news/sports/wp/2017/10/29/nfl-week-8-owner-bob-mcnair-has-texans-on-edge-browns-vikings-start-day-in-london/?tid=pm_sports_pop
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2017/10/29/i-just-wasnt-his-guy-robert-griffin-iii-opens-up-about-jay-gruden-redskins-on-twitter/?tid=pm_sports_pop
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2017/10/29/best-and-worst-moments-from-the-redskins-cowboys-game-at-fedex-field/
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2017/10/28/redskins-terrelle-pryor-sr-apologizes-to-fans-and-teammates-for-slow-start/
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2017/10/27/president-trump-confused-lee-greenwood-the-singer-with-my-fantasy-football-commissioner/
# https://www.washingtonpost.com/news/fancy-stats/wp/2017/10/26/only-the-bears-and-bills-are-using-wide-receivers-less-than-the-redskins/
# https://www.washingtonpost.com/news/fancy-stats/wp/2017/10/26/the-rams-have-done-everything-possible-to-make-jared-goffs-job-easier-its-paying-off/
# https://www.washingtonpost.com/news/fancy-stats/wp/2017/10/26/nfl-week-8-power-rankings-ats-picks-eagles-soar-rams-on-the-move/
# https://www.washingtonpost.com/news/fancy-stats/wp/2017/10/25/fantasy-football-startsit-for-week-8-expect-kareem-hunts-struggles-to-continue/
# https://www.washingtonpost.com/news/football-insider/wp/2017/10/29/pro-bowl-lt-trent-williams-ruled-out-for-sundays-game-against-dallas/
# https://www.washingtonpost.com/news/football-insider/wp/2017/10/29/showdown-with-cowboys-promises-to-be-rainy-affair-for-kirk-cousins-and-redskins/
# https://www.washingtonpost.com/news/nationals-journal/wp/2017/10/28/dave-martinez-is-a-finalist-for-nationals-manager-job-but-no-deal-done/
# https://www.washingtonpost.com/news/nationals-journal/wp/2017/10/27/john-farrell-is-the-latest-candidate-for-the-nationals-managerial-opening/
# https://www.washingtonpost.com/news/nationals-journal/wp/2017/10/27/nationals-payroll-entering-offseason/
# https://www.washingtonpost.com/news/capitals-insider/wp/2017/10/29/after-racking-up-assists-caps-evgeny-kuznetsov-now-has-three-goals-in-past-two-games/
# https://www.washingtonpost.com/news/capitals-insider/wp/2017/10/28/forward-devante-smith-pelly-rewarded-for-his-consistency-with-the-capitals/
# https://www.washingtonpost.com/news/capitals-insider/wp/2017/10/28/every-human-can-do-something-alex-ovechkin-buys-a-homeless-man-clothes-in-edmonton/
# https://www.washingtonpost.com/news/capitals-insider/wp/2017/10/27/brett-connolly-expected-to-miss-at-least-next-two-games-capitals-recall-anthony-peluso/
# https://www.washingtonpost.com/news/wizards-insider/wp/2017/10/28/bradley-beal-optimistic-still-expects-suspension-for-scuffle-with-draymond-green/
# https://www.washingtonpost.com/news/wizards-insider/wp/2017/10/28/come-on-little-bro-back-away-kevin-durant-kept-john-wall-out-of-wizards-warriors-scuffle/
# https://www.washingtonpost.com/news/soccer-insider/wp/2017/10/29/in-d-c-a-small-step-toward-tackling-u-s-youth-soccers-accessibility-problem/
# https://www.washingtonpost.com/news/soccer-insider/wp/2017/10/26/a-college-soccer-player-lost-her-hearing-last-summer-but-not-her-starting-spot/
# https://www.washingtonpost.com/news/soccer-insider/wp/2017/10/25/its-now-official-bill-hamid-is-leaving-d-c-united/
# https://www.washingtonpost.com/news/terrapins-insider/wp/2017/10/19/anthony-cowan-jr-and-maryland-get-ready-for-life-after-melo-trimble/
# https://www.washingtonpost.com/news/terrapins-insider/wp/2017/10/16/maryland-athletic-director-kevin-anderson-to-go-on-six-month-sabbatical/
# https://www.washingtonpost.com/news/terrapins-insider/wp/2017/10/14/university-of-maryland-says-kevin-anderson-remains-athletic-director-after-reports-of-ouster/
# https://www.washingtonpost.com/news/terrapins-insider/wp/2017/10/10/maryland-qb-max-bortenschlager-is-day-to-day-hasnt-been-cleared-for-northwestern-game/
# https://www.nytimes.com/2017/10/26/business/big-tech-company-earnings.html
# https://www.nytimes.com/2017/10/26/technology/twitter-russia.html
# https://www.nytimes.com/2017/10/26/technology/twitter-russia-today-sputnik.html
# https://www.nytimes.com/2017/10/26/us/reddit-violence-policy.html
# https://www.nytimes.com/2017/10/27/technology/personaltech/iphone-raise-to-wake.html
# https://www.nytimes.com/2017/10/26/technology/personaltech/scanning-converting-and-editing-text-on-the-go.html
# https://www.nytimes.com/2017/10/25/technology/personaltech/google-keys-advanced-protection-program.html
# https://www.nytimes.com/2017/10/25/technology/personaltech/storage-space-mac.html
# https://www.nytimes.com/2017/10/25/technology/personaltech/australia-technology.html
# https://www.nytimes.com/2017/10/29/technology/mark-warner-tech-critic-russia.html
# https://www.nytimes.com/2017/10/29/business/virtual-reality-driverless-cars.html
# https://www.nytimes.com/2017/10/28/style/virtual-reality-porn.html
# https://www.nytimes.com/2017/10/28/style/amazon-key-1-click-buyers-remorse.html
# https://www.nytimes.com/2017/10/27/technology/amazon-pharmacy-drugs.html
# https://www.nytimes.com/2017/10/27/technology/facebook-fake-content-employees.html
# https://www.nytimes.com/2017/10/27/world/asia/myanmar-government-facebook-rohingya.html
# https://www.nytimes.com/2017/10/27/world/europe/uk-ransomware-hack-north-korea.html
# https://www.nytimes.com/2017/10/27/arts/politicians-are-bad-at-podcasting.html
# https://www.nytimes.com/2017/10/27/technology/how-floyd-mayweather-helped-two-young-guys-from-miami-get-rich.html
# https://www.nytimes.com/2017/10/27/technology/what-is-an-initial-coin-offering.html
# https://www.nytimes.com/2017/10/27/technology/farhad-and-mikes-week-in-tech-twitter-and-reddit-take-a-stand.html
# https://www.nytimes.com/2017/10/26/business/detroit-automakers.html
# https://www.nytimes.com/2017/10/26/style/driving-cross-country-without-checking-your-phone.html
# https://www.nytimes.com/2017/10/26/technology/twitter-q3-earnings-trolls.html
# https://www.nytimes.com/2017/10/25/technology/fcc-media-ownership-rules.html
# https://www.nytimes.com/2017/10/25/technology/amazon-key-home.html
# https://www.nytimes.com/2017/10/25/technology/regulating-tech-companies.html
# https://www.nytimes.com/2017/10/25/technology/big-tech-government-regulation.html
# https://www.nytimes.com/2017/10/25/technology/trump-drone-testing.html
# https://www.nytimes.com/2017/10/30/sports/baseball/astros-win-game-5.html
# https://www.nytimes.com/2017/10/29/sports/football/nfl-anthem-lockhart.html
# https://www.nytimes.com/2017/10/29/sports/nfl-scores-texans-seahawks.html
# https://www.nytimes.com/2017/10/29/sports/baseball/next-dodgers-and-astros-are-quick-to-pull-pitchers.html
# https://www.nytimes.com/2017/10/29/sports/world-series-dodgers-astros.html
# https://www.nytimes.com/2017/10/28/sports/football/texans-bob-mcnair-.html
# https://www.nytimes.com/2017/10/29/sports/tennis/martina-hingis-retire.html
# https://www.nytimes.com/2017/10/29/sports/baseball/world-series-dodgers-astros.html
# https://www.nytimes.com/2017/10/27/sports/basketball/nba-brooklyn-nets-3-pointers.html
# https://www.nytimes.com/2017/10/30/sports/soccer/bradley-wright-phillips-red-bulls-mls-playoffs.html
# https://www.nytimes.com/2017/10/30/sports/knicks-cavaliers-hardaway-porzingis.html
# https://www.nytimes.com/2017/10/29/sports/baseball/slick-baseballs-world-series.html
# https://www.nytimes.com/2017/10/29/sports/baseball/brian-mccann-astros.html
# https://www.nytimes.com/2017/10/28/sports/baseball/with-one-gesture-yuli-gurriel-upends-his-impressive-season.html
# https://www.nytimes.com/2017/10/28/sports/baseball/yuli-gurriel-apologizes-racist-yu-darvish.html
# https://www.nytimes.com/2017/10/28/sports/baseball/astros-dodgers-world-series.html
# https://www.nytimes.com/2017/10/27/sports/knicks-nets-nba.html
# https://www.nytimes.com/2017/10/27/sports/baseball/astros-dodgers-friedman-luhnow.html
# https://www.nytimes.com/2017/10/27/sports/baseball/yankees-trade-mccann-beltran.html
# https://www.nytimes.com/2017/10/27/obituaries/terry-laughlin-dead-taught-swimmers-not-to-struggle-with-total-immersion-method.html
# https://www.nytimes.com/2017/10/27/opinion/baseball-collection-memorabilia.html
# https://www.nytimes.com/2017/10/27/sports/football/bob-mcnair-texans.html
# https://www.nytimes.com/2017/10/27/sports/world-series-dodgers-astros.html
# https://www.nytimes.com/2017/10/27/sports/new-rule-opens-up-jobs-for-female-sailors-at-the-volvo-ocean-race.html
# https://www.nytimes.com/2017/10/27/sports/baseball/alex-bregman-astros-world-series.html
# https://www.nytimes.com/2017/10/27/business/media/nfl-six-second-commercials.html
# https://www.nytimes.com/2017/10/27/sports/rugby/rugby-world-cup-league-and-union.html
# https://www.nytimes.com/2017/10/27/sports/golf/tiger-woods-reckless-driving.html
# https://www.nytimes.com/2017/10/27/business/brooklyn-nets-joseph-tsai-alibaba.html

# %%
# Now let's collect these article summaries in an easy to classify form
articleSummaries = {}
for techUrlDictionary in [newYorkTimesTechArticles, washingtonPostTechArticles]:
    print '00'
    for articleUrl in techUrlDictionary:
        print '0'
        if techUrlDictionary[articleUrl][0] is not None:
            print '1'
            if len(techUrlDictionary[articleUrl][0]) > 0:
                fs = FrequencySummarizer()
                summary = fs.extractFeatures(techUrlDictionary[articleUrl],25)
                print '2'
                articleSummaries[articleUrl] = {'feature-vector': summary,
                                               'label': 'Tech'}
for nontechUrlDictionary in [newYorkTimesNonTechArticles, washingtonPostNonTechArticles]:
    for articleUrl in nontechUrlDictionary:
        if nontechUrlDictionary[articleUrl][0] is not None:
            if len(nontechUrlDictionary[articleUrl][0]) > 0:
                fs = FrequencySummarizer()
                summary = fs.extractFeatures(nontechUrlDictionary[articleUrl],25)
                articleSummaries[articleUrl] = {'feature-vector': summary,
                                               'label': 'Non-Tech'}
# Out:
# 00
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 00
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 0
# 1
# 0
# 1
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2

# %%
def getDoxyDonkeyText(testUrl,token):
    response = requests.get(testUrl)
    soup = BeautifulSoup(response.content)
    page = str(soup)
    title = soup.find("title").text
    mydivs = soup.findAll("div", {"class":token})
    text = ''.join(map(lambda p:p.text,mydivs))
    return text,title
    # our test instance, just like our training data, is nicely
    # setup as a (title,text) tuple

testUrl = "http://doxydonkey.blogspot.tw"
testArticle = getDoxyDonkeyText(testUrl,"post-body")

fs = FrequencySummarizer()
testArticleSummary = fs.extractFeatures(testArticle, 25)
testArticleSummary
# Out:
# [u'company',
#  u'china',
#  u'new',
#  u'said',
#  u'year',
#  u'billion',
#  u'uber',
#  u'million',
#  u'percent',
#  u'technology',
#  u'people',
#  u'could',
#  u'investors',
#  u'amazon',
#  u'drivers',
#  u'india',
#  u'1',
#  u'chief',
#  u'money',
#  u'like',
#  u'bitcoin',
#  u'companies',
#  u'pinterest',
#  u'years',
#  u'funding']

# %%
similarities = {}
for articleUrl in articleSummaries:
    oneArticleSummary = articleSummaries[articleUrl]['feature-vector']
    similarities[articleUrl] = len(set(testArticleSummary).intersection(set(oneArticleSummary)))

labels = defaultdict(int)    
knn = nlargest(5, similarities, key=similarities.get)
for oneNeighbor in knn:
    labels[articleSummaries[oneNeighbor]['label']] += 1

nlargest(1,labels,key=labels.get)
# Out:
# ['Tech']

# %%
cumulativeRawFrequencies = {'Tech':defaultdict(int),'Non-Tech':defaultdict(int)}
trainingData = {'Tech':newYorkTimesTechArticles,'Non-Tech':newYorkTimesNonTechArticles}
for label in trainingData:
    for articleUrl in trainingData[label]:
        if len(trainingData[label][articleUrl][0]) > 0:
            fs = FrequencySummarizer()
            rawFrequencies = fs.extractRawFrequencies(trainingData[label][articleUrl])
            for word in rawFrequencies:
                cumulativeRawFrequencies[label][word] += rawFrequencies[word]

# %%
techiness = 1.0
nontechiness = 1.0
for word in testArticleSummary:
    # for each 'feature' of the test instance - 
    if word in cumulativeRawFrequencies['Tech']:
        techiness *= 1e3*cumulativeRawFrequencies['Tech'][word] / float(sum(cumulativeRawFrequencies['Tech'].values()))
        # we multiply the techiness by the probability of this word
        # appearing in a tech article (based on the training data)
    else:
        techiness /= 1e3
        # THis is worth paying attention to. If the word does not appear
        # in the tech articles of the training data at all,we could simply
        # set that probability to zero - in fact doing so is the 'correct'
        # way mathematically, because that way all of the probabilities would
        # sum to 1. But that would lead to 'snap' decisions since the techiness
        # would instantaneously become 0. To prevent this, we decide to take
        # the probability as some very small number (here 1 in 1000, which is 
        # actually not all that low)
    # Now the exact same deal- but for the nontechiness. We are intentionally
    # copy-pasting code (not a great software development practice) in order
    # to make the logic very clear. Ideally, we would have created a function
    # and called it twice rather than copy-pasting this code. In any event..
    if word in cumulativeRawFrequencies['Non-Tech']:
        nontechiness *= 1e3*cumulativeRawFrequencies['Non-Tech'][word] / float(sum(cumulativeRawFrequencies['Non-Tech'].values()))
        # we multiply the techiness by the probability of this word
        # appearing in a tech article (based on the training data)
    else:
        nontechiness /= 1e3

# %%
# we are almost done! Now we simply need to scale the techiness 
# and non-techiness by the probabilities of overall techiness and
# non-techiness. THis is simply the number of words in the tech and 
# non-tech articles respectively, as a proportion of the total number
# of words
techiness *= float(sum(cumulativeRawFrequencies['Tech'].values())) / (float(sum(cumulativeRawFrequencies['Tech'].values())) + float(sum(cumulativeRawFrequencies['Non-Tech'].values())))
nontechiness *= float(sum(cumulativeRawFrequencies['Non-Tech'].values())) / (float(sum(cumulativeRawFrequencies['Tech'].values())) + float(sum(cumulativeRawFrequencies['Non-Tech'].values())))
if techiness > nontechiness:
    label = 'Tech'
else:
    label = 'Non-Tech'
print label, techiness, nontechiness
# Out:
# Tech 0.00059343500534 9.74051982668e-28

# %%
def getAllDoxyDonkeyPosts(url,links):
    request = urllib2.Request(url)
    response = urllib2.urlopen(request)
    soup = BeautifulSoup(response)
    for a in soup.findAll('a'):
        try:
            url = a['href']
            title = a['title']
            if title == "Older Posts":
                print title, url
                links.append(url)
                getAllDoxyDonkeyPosts(url,links)
        except:
            title = ""
    return

# %%
blogUrl = "http://doxydonkey.blogspot.in"
links = []
getAllDoxyDonkeyPosts(blogUrl,links)
doxyDonkeyPosts = {}
for link in links:
    doxyDonkeyPosts[link] = getDoxyDonkeyText(link,'post-body')


documentCorpus = []
for onePost in doxyDonkeyPosts.values():
    documentCorpus.append(onePost[0])
# Out:
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-05-23T19:53:00-07:00&max-results=7
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-05-14T19:02:00-07:00&max-results=7&start=7&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-05-02T19:43:00-07:00&max-results=7&start=14&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-04-17T19:26:00-07:00&max-results=7&start=21&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-04-10T18:56:00-07:00&max-results=7&start=28&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-03-30T19:57:00-07:00&max-results=7&start=35&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-03-20T19:47:00-07:00&max-results=7&start=42&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-03-02T17:42:00-08:00&max-results=7&start=49&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-02-21T19:13:00-08:00&max-results=7&start=56&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-02-12T18:34:00-08:00&max-results=7&start=63&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-02-01T18:56:00-08:00&max-results=7&start=70&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-01-22T18:58:00-08:00&max-results=7&start=77&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-01-11T18:09:00-08:00&max-results=7&start=84&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2017-01-02T17:59:00-08:00&max-results=7&start=91&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-12-22T18:58:00-08:00&max-results=7&start=98&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-12-13T18:57:00-08:00&max-results=7&start=105&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-12-04T18:58:00-08:00&max-results=7&start=112&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-09-09T07:34:00-07:00&max-results=7&start=119&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-08-28T20:08:00-07:00&max-results=7&start=126&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-08-17T19:24:00-07:00&max-results=7&start=133&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-08-07T20:30:00-07:00&max-results=7&start=140&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-07-26T19:55:00-07:00&max-results=7&start=147&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-07-17T19:47:00-07:00&max-results=7&start=154&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-07-06T19:34:00-07:00&max-results=7&start=161&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-06-26T19:36:00-07:00&max-results=7&start=168&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-06-15T19:23:00-07:00&max-results=7&start=175&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-06-06T18:50:00-07:00&max-results=7&start=182&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-05-26T20:08:00-07:00&max-results=7&start=189&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-05-17T18:52:00-07:00&max-results=7&start=196&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-05-06T19:26:00-07:00&max-results=7&start=203&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-04-27T19:03:00-07:00&max-results=7&start=210&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-04-19T19:36:00-07:00&max-results=7&start=217&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-04-10T19:19:00-07:00&max-results=7&start=224&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-03-30T19:12:00-07:00&max-results=7&start=231&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-03-20T18:41:00-07:00&max-results=7&start=238&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-03-09T18:38:00-08:00&max-results=7&start=245&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-02-28T17:47:00-08:00&max-results=7&start=252&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-02-17T18:44:00-08:00&max-results=7&start=259&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-02-08T18:13:00-08:00&max-results=7&start=266&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-01-28T19:45:00-08:00&max-results=7&start=273&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-01-18T18:30:00-08:00&max-results=7&start=280&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2016-01-07T19:03:00-08:00&max-results=7&start=287&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-12-28T18:26:00-08:00&max-results=7&start=294&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-12-16T18:24:00-08:00&max-results=7&start=301&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-12-07T18:24:00-08:00&max-results=7&start=308&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-11-26T17:49:00-08:00&max-results=7&start=315&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-11-17T18:18:00-08:00&max-results=7&start=322&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-11-05T20:15:00-08:00&max-results=7&start=329&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-10-27T20:04:00-07:00&max-results=7&start=336&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-10-12T19:45:00-07:00&max-results=7&start=343&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-09-30T19:33:00-07:00&max-results=7&start=350&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-09-20T19:11:00-07:00&max-results=7&start=357&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-09-09T19:32:00-07:00&max-results=7&start=364&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-08-31T19:31:00-07:00&max-results=7&start=371&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-08-20T19:29:00-07:00&max-results=7&start=378&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-08-11T19:32:00-07:00&max-results=7&start=385&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-08-02T19:04:00-07:00&max-results=7&start=392&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-07-22T19:39:00-07:00&max-results=7&start=399&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-07-13T19:38:00-07:00&max-results=7&start=406&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-07-02T21:15:00-07:00&max-results=7&start=413&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-06-23T19:30:00-07:00&max-results=7&start=420&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-06-14T19:36:00-07:00&max-results=7&start=427&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-06-02T19:38:00-07:00&max-results=7&start=434&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-05-24T20:16:00-07:00&max-results=7&start=441&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-05-13T20:18:00-07:00&max-results=7&start=448&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-05-04T20:23:00-07:00&max-results=7&start=455&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-04-23T20:19:00-07:00&max-results=7&start=462&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-04-14T19:40:00-07:00&max-results=7&start=469&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-04-05T20:22:00-07:00&max-results=7&start=476&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-03-24T20:12:00-07:00&max-results=7&start=483&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-03-15T20:41:00-07:00&max-results=7&start=490&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-03-03T19:30:00-08:00&max-results=7&start=497&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-02-22T19:55:00-08:00&max-results=7&start=504&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-02-11T20:02:00-08:00&max-results=7&start=511&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-02-02T19:46:00-08:00&max-results=7&start=518&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-01-22T19:50:00-08:00&max-results=7&start=524&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-01-15T19:17:00-08:00&max-results=7&start=529&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2015-01-06T19:48:00-08:00&max-results=7&start=536&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2014-12-25T21:30:00-08:00&max-results=7&start=543&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2014-12-15T19:24:00-08:00&max-results=7&start=550&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2014-12-05T01:52:00-08:00&max-results=7&start=557&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2014-11-26T01:44:00-08:00&max-results=7&start=564&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2014-11-17T01:41:00-08:00&max-results=7&start=571&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2014-11-06T01:38:00-08:00&max-results=7&start=578&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2014-10-28T01:24:00-07:00&max-results=7&start=585&by-date=false
# Older Posts http://doxydonkey.blogspot.tw/search?updated-max=2014-10-17T01:20:00-07:00&max-results=7&start=592&by-date=false

# %%
vectorizer = TfidfVectorizer(max_df=0.5,min_df=2,stop_words='english')
X = vectorizer.fit_transform(documentCorpus)
km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 100, n_init = 1, verbose = True)
km.fit(X)

keywords = {}
for i,cluster in enumerate(km.labels_):
    oneDocument = documentCorpus[i]
    fs = FrequencySummarizer()
    summary = fs.extractFeatures((oneDocument,""),
                                100,
                                [u"according",u"also",u"billion",u"like",u"new", u"one",u"year",u"first",u"last"])
    if cluster not in keywords:
        keywords[cluster] = set(summary)
    else:
        keywords[cluster] = keywords[cluster].intersection(set(summary))
# Out:
# Initialization complete
# Iteration  0, inertia 137.665
# Iteration  1, inertia 71.685
# Converged at iteration 1: center shift 0.000000e+00 within tolerance 7.274641e-09

# %%
summary
# Out:
# [u'company',
#  u'said',
#  u'apple',
#  u'uber',
#  u'\u201c',
#  u'\u201d',
#  u'china',
#  u'would',
#  u'square',
#  u'facebook',
#  u'service',
#  u'people',
#  u'many',
#  u'iphone',
#  u'users',
#  u'companies',
#  u'phone',
#  u'public',
#  u'\u2014',
#  u'rift',
#  u'growth',
#  u'market',
#  u'``',
#  u'investors',
#  u'ola',
#  u'may',
#  u'business',
#  u'technology',
#  u'machine',
#  u'make',
#  u'product',
#  u'million',
#  u'mr.',
#  u'learning',
#  u'google',
#  u'percent',
#  u'government',
#  u'even',
#  u'cars',
#  u'snapchat',
#  u'customers',
#  u'system',
#  u'content',
#  u"''",
#  u'fiber',
#  u'businesses',
#  u'tay',
#  u'buy']
